# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.preprocessing import image
import numpy as np 
import pickle
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image  #pyhton image library
import cv2 #opencv
from matplotlib import pyplot
from mtcnn import MTCNN

# %%
import os

fol = "Bollywood_celeb_face_localized"
folders = os.listdir(fol)
filenames = []

for folder in folders:
     for actor in os.listdir(os.path.join(fol,folder)):
        for file in os.listdir(os.path.join(fol,folder,actor)):
            filenames.append(os.path.join(fol,folder,actor,file))

# %%
pickle.dump(filenames,open('filename.pkl','wb'))

# %%
model = keras.applications.resnet50.ResNet50(
    include_top=False,
    input_shape=(224,224,3),
    pooling='avg'
)

# %%
def feature_extractor(img_path,model):
    img = image.load_img(img_path,target_size=(224,224))
    img_array = image.img_to_array(img)
    expanded_img = np.expand_dims(img_array,axis=0)
    preprocessed_img = keras.applications.efficientnet.preprocess_input(expanded_img)
    result = model.predict(preprocessed_img).flatten()

    return result

# %%
features=[]
for file in tqdm(filenames):
    features.append(feature_extractor(file,model))
# Out:
#   0%|          | 0/8664 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#   0%|          | 1/8664 [00:03<8:14:49,  3.43s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
#   0%|          | 2/8664 [00:03<3:43:25,  1.55s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#   0%|          | 3/8664 [00:03<2:13:35,  1.08it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#   0%|          | 4/8664 [00:04<1:33:30,  1.54it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#   0%|          | 5/8664 [00:04<1:09:34,  2.07it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#   0%|          | 6/8664 [00:04<55:39,  2.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
#   0%|          | 7/8664 [00:04<46:53,  3.08it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
#   0%|          | 8/8664 [00:04<41:06,  3.51it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#   0%|          | 9/8664 [00:05<37:16,  3.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#   0%|          | 10/8664 [00:05<35:25,  4.07it/s]
# ...

# %%
pickle.dump(features,open('embeddings.pkl','wb'))

# %%
feature_list = np.array(pickle.load(open('embeddings.pkl','rb')))
filename2 = pickle.load(open('filename.pkl','rb'))

# %%
model = keras.applications.resnet50.ResNet50(
    include_top=False,
    input_shape=(224,224,3),
    pooling='avg'
)

# %%
detector = MTCNN()

# %%
import os 
os.getcwd()
path = os.path.join(os.getcwd(),'Bollywood_celeb_face_localized','bollywood_celeb_faces2','Varun_Dhawan')
print(path)
# sample_img  = os.listdir(path)[0]
# Out:
# c:\Users\shiva\OneDrive\Desktop\Bollywood_facial_checking\Bollywood_celeb_face_localized\bollywood_celeb_faces2\Varun_Dhawan
# 'Varun_Dhawan.100.jpg'

# %%
img_path = os.listdir(path)[0]
# print(img_path)
sample_img = cv2.imread(r'Bollywood_celeb_face_localized\bollywood_celeb_faces2\Varun_Dhawan\Varun_Dhawan.31.jpg')
# print(sample_img,type(sample_img))
result = detector.detect_faces(sample_img)
x,y,width,height = result[0]['box']
print(x,y,width,height)
face = sample_img[y:y+height,x:x+width]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 8 1 47 61

# %%
image = Image.fromarray(face)
image = image.resize((224,224))

fa = np.asarray(image)
fa = fa.astype('float32')

expanded_img = np.expand_dims(fa, axis=0)
preprocessed_img = keras.applications.efficientnet.preprocess_input(expanded_img)
result = model.predict(preprocessed_img).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
si = []
for i in range(len(feature_list)):
    si.append(cosine_similarity(result.reshape(1,-1),feature_list[i].reshape(1,-1))[0][0])
    index_pos = sorted(list(enumerate(si)),reverse = True, key = lambda x:x[1])
    position = []
    for pos in index_pos:
        position.append(list(pos)[0])
    predictImage = []
    for pos in position[:5]:
        predictImage.append(cv2.imread(filename2[pos]))

# %%
pyplot.imshow(face)
pyplot.show()
